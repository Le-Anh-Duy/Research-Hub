# %% [markdown]
# # Colab runner — ví dụ
# Notebook này CHỈ orchestration. Logic thật nằm trong `code/src/`. Copy và đổi tên notebook này mỗi khi bắt đầu 1 experiment mới.

# %%
# !git clone https://github.com/<your-username>/<your-repo>.git
# %cd <your-repo>/vault/code
# !pip install -r requirements.txt -q

# %%
from src.training.run_experiment import run_experiment
run_experiment("configs/example.yaml")
